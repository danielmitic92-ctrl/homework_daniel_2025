# %% [markdown]
# # Rosalind complementing a dna strand

# %%
##rosalind complementing a dna strand
dna="..."
complement=dna.replace ("A","X")
complement=complement.replace ("C","Z")
complement=complement.replace ("T","A")
complement=complement.replace ("G","C")
complement=complement.replace ("X","T")
complement=complement.replace ("Z","G")

complement
reverse_complement=complement[::-1]
print(reverse_complement)
# Out:
# ...

# %%
#solving it with a for loop
dna="AAAACCCGGT"
reverse_complement=""
for base in dna:
    if base=="A":
        reverse_complement="T"+reverse_complement
    if base=="C":
        reverse_complement="G"+reverse_complement
    if base=="T":
        reverse_complement="A"+reverse_complement
    if base=="G":
        reverse_complement="C"+reverse_complement

# %%
reverse_complement
# Out:
# 'ACCGGGTTTT'
