# %% [markdown]
# # Rosalind Finding a Motif in DNA (SUBS)
# https://rosalind.info/problems/subs/

# %%
s="GATATATGCATATACTT"
t="ATAT"

# %%
s="..."

# %%
t="ATACTTAAT"

# %%
motif_locations=[]
for i in range(len(s)):
    current_motif=s[i:i+len(t)]
    if current_motif==t:
        motif_locations.append(i+1)
        print(i+1,end=" ")
# Out:
# 1 13 59 151 166 173 180 292 326 374 425 479 510 558 573 607 676 683 727 734 741

# %%
import util
test=util.motif_locations(s,t)
