# %%
number=2
import numpy as np

seq = np.arange(1, number+1).tolist()
print(seq)
# Out:
# [1, 2]

# %%
seq=[-1,2]

# %%
combined = []

for pair in itertools.product([-1,2], [-2,1]):
    print(pair)

for pair in itertools.product([1,-2], [2,-1]):
    print(pair)
# Out:
# (-1, -2)
# (-1, 1)
# (2, -2)
# (2, 1)
# (1, 2)
# (1, -1)
# (-2, 2)
# (-2, -1)

# %%
from itertools import permutations

perm = permutations(seq)
all_combinations=[]
for i in perm:
    #print(i)
    all_combinations.append(i)

# %%
all_combinations
# Out:
# [(1, 2), (2, 1)]

# %%
for combination in all_combinations:
    for i in range(len(combination)):
        #if i < len(combination)-1:
            #positive=combination[i]
            #negative=combination[i+1] *-1
            #print(negative, positive)
            #print(positive,negative)
        
        combination[i]*1
# Out:
# -2 1
# 1 -2
# -1 2
# 2 -1

# %%
all_combinations[0] [0]
# Out:
# 1

# %%
number=2
import numpy as np

positives = np.arange(1, number+1).tolist()
negatives=positives*-1
positives.tolist()
negatives.tolist()
#all_numbers = np.concatenate((positives, negatives)).tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 6
#       4 positives = np.arange(1, number+1).tolist()
#       5 negatives=positives*-1
# ----> 6 positives.tolist()
#       7 negatives.tolist()
#       8 #all_numbers = np.concatenate((positives, negatives)).tolist()
#
# AttributeError: 'list' object has no attribute 'tolist'

# %%
combined = []
import itertools
for pair in itertools.product(positives, negatives):
    #combined.append(''.join(pair))
    print(pair)
# Out:
# (np.int64(1), np.int64(-1))
# (np.int64(1), np.int64(-2))
# (np.int64(2), np.int64(-1))
# (np.int64(2), np.int64(-2))

# %%
combined
# Out:
# ['ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']

# %%
from itertools import permutations

perm = permutations(positives)
all_combinations=[]
for i in perm:
    #print(i)
    all_combinations.append(i)

# %%
all_combinations
# Out:
# [(np.int64(1), np.int64(2)), (np.int64(2), np.int64(1))]
