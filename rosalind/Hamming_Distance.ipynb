# %% [markdown]
# # Hamming Distance
# https://rosalind.info/problems/hamm/

# %%
#hamming distance
seq_1="..."
seq_2="..."

differnces=0
for i,base in enumerate(seq_1):
    if base != seq_2[i]:
        differnces=differnces+1
print(differnces)
# Out:
# 469

# %%
#alternative way of solving it:
a = "string1"
b = "string2"
n = len(a)
no_mismatches = 0
for i in range(n):
    if a[i] != b[i]:
        no_mismatches += 1
print(no_mismatches)
# Out:
# 1
