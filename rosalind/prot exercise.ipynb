# %% [markdown]
# ## Prot exercise
# https://rosalind.info/problems/prot/

# %%
rna="AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUAACGGGUGA"

# %%
rna="..."

# %%
import util
file_path="/Users/danielmitic/Downloads/rosalind_prot.txt"
rna=util.read_file_into_lines(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 import util
#       2 file_path="/Users/danielmitic/Downloads/rosalind_prot.txt"
# ----> 3 rna=util.read_file_into_lines(file_path)
#
# File ~/Desktop/homework_daniel_2025/rosalind/util.py:6, in read_file_into_lines(file_path)
#       2 """"
#       3 read file and remove the character at the end
#       4 """
#       5 lines=[]
# ----> 6 with open (file_path,"r") as infile:
#       7   for line in infile.readlines():
#       8       cleaned=line.rstrip()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/danielmitic/Downloads/rosalind_prot.txt'

# %%
#rna as a string
rna=rna[0]

# %%
codon_aa_table=util.load_codon_table()

# %%
peptide=""
counter=0
for base in rna:
    triplet=rna[counter:counter+3]
    print(triplet)
    if triplet!="" :
        counter=counter+3
        aa=codon_aa_table[triplet]
        peptide=peptide+aa
# Out:
# AUG
# GCC
# AUG
# GCG
# CCC
# AGA
# ACU
# GAG
# AUC
# AAU
# AGU
# ACC
# CGU
# AUU
# AAC
# GGG
# UGA

# %%
#as a function
test=util.translate_protein(rna,codon_aa_table)

# %%
test
# Out:
# 'MAMAPRTEINSTRING'
