# %% [markdown]
# # Rosalind Mendels first law
# https://rosalind.info/problems/iprb/

# %%
k=16
m=22
n=25
N=(k+m+n)

# %%
x=(k/N) + ((m/(N*(N-1))) * ((4*k+3*m+2*n-3)/4) + n/(N*(N-1)) * ((2*k+m)/2))

# %%
x
# Out:
# 0.6760112647209422
