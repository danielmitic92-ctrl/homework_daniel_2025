# %% [markdown]
# # Counting DNA Nucleotides
# http://rosalind.info/problems/dna/

# %%
dna="..."
count_A=dna.count("A")
count_C=dna.count("C")
count_G=dna.count("G")
count_T=dna.count("T")
print(count_A, count_C, count_G, count_T)
