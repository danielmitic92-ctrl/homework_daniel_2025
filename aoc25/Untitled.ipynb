# %%
test=[[162,817,812],
[57,618,57],
[906,360,560],
[592,479,940],
[352,342,300],
[466,668,158],
[542,29,236],
[431,825,988],
[739,650,466],
[52,470,668],
[216,146,977],
[819,987,18],
[117,168,530],
[805,96,715],
[346,949,466],
[970,615,88],
[941,993,340],
[862,61,35],
[984,92,344],
[425,690,689]]

# %%
##import modules
import numpy as np
from math import sqrt

# %%
##functions:
def euclidian_distance(list_1,list_2):
    distance=sqrt((list_2[0]-list_1[0])**2 + (list_2[1]-list_1[1])**2 + (list_2[2]-list_1[2])**2)
    return distance

# %%
##empty array as container
distances = np.full((20, 20), 0)

# %%
for i in range(len(distances)):
    for j in range(len(distances[i])):
        distance=euclidian_distance(test[i],test[j])
        distances[i][j]=distance

# %%
distances
# Out:
# array([[   0,  787,  908,  561,  723,  736, 1047,  321,  693,  391,  693,
#         1044,  709,  970,  413, 1103,  927, 1290, 1191,  316],
#        [ 787,    0, 1019, 1041,  471,  424,  783, 1024,  795,  628, 1046,
#          847,  655, 1124,  600,  913, 1001,  979, 1103,  734],
#        [ 908, 1019,    0,  507,  612,  670,  589,  790,  347,  867,  834,
#          833,  812,  322,  818,  540,  671,  605,  352,  597],
#        [ 561, 1041,  507,    0,  697,  814,  837,  384,  524,  604,  503,
#         1076,  700,  492,  711,  941,  863, 1032,  811,  367],
#        [ 723,  471,  612,  697,    0,  373,  371,  844,  521,  491,  717,
#          844,  372,  661,  629,  708,  878,  639,  681,  527],
#        [ 736,  424,  670,  814,  373,    0,  648,  845,  411,  686, 1002,
#          495,  714,  867,  433,  511,  603,  735,  796,  533],
#        [1047,  783,  589,  837,  371,  648,    0, 1100,  690,  788,  817,
#         1020,  535,  550,  968,  740, 1048,  379,  459,  809],
# ...

# %%
min_distance=sorted_distance[0][1]

# %%
min_distance
# Out:
# np.int64(316)

# %%
index_min_distance=np.where(distances == 316)

# %%
index_min_distance
# Out:
# (array([ 0, 19]), array([19,  0]))
