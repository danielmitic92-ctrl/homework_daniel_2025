# %% [markdown]
# # Variables Assignment
# https://galicae.github.io/python-novice/02-variables.html

# %%
age = 42
first_name = 'Ahmed'

# %%
print(first_name, 'is', age, 'years old')
# Out:
# Ahmed is 42 years old

# %%
age = age + 3
print('Age in three years:', age)'
# Out:
# Age in three years: 45

# %% [markdown]
# ## rosalind ini2

# %%
a=804
b=885
a**2 + b**2
# Out:
# 1429641

# %%
x = 5
x += 3
print(x)
# Out:
# 8

# %%
atom_name = 'helium'
print(atom_name[0])
# Out:
# h

# %%
atom_name = 'sodium'
print(atom_name[0:3])
# Out:
# sod

# %%
print(len('helium'))
# Out:
# 6

# %% [markdown]
# ## Rosalind INI3

# %%
s="CorvuslSRViCnbUNQNlMfxMAUXquaAIJVuAplatycephalarzJF7AKOOiiOUZ3KDEELY5RZrjWikPzzcZES25Ypt5t72hHCDBctUtQ0EhODW7TKLkrIe7CWuzsEo3jaTT1SiqJfmQclkjbKua6h42v0HZSq0MGnVt0mMTy3z3KsC."
a=0
b=5
c=35
d=46

# %%
print(s[a:b+1],s[c:d+1])
# Out:
# Corvus platycephala
